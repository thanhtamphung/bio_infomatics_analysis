# %% [markdown]
# # Burden test:
#     Date: 13 mar 2019
#     Last Edit: 18 mar 2019
#     Install all dependencies
#     Ref: Rvtest https://genome.sph.umich.edu/wiki/Rvtests
#          Exomiser https://www.sanger.ac.uk/science/tools/exomiser
#     Run cells step by step

# %% [markdown]
# ## Dependencies:
#
#     1/ python packages in import cell
#     2/ bedtools
#     3/ vcftools (vcf-subset, vcf-sort, vcf-merge)
#     4/ htslib (bgzip, tabix)
#     5/ exomiser 8.0.0 https://github.com/exomiser/Exomiser/releases/tag/8.0.0
#     6/ rvtests https://github.com/zhanxw/rvtests

# %% [markdown]
# # Burden test Framework

# %% [markdown]
# ## 1/ Review data
# ## 2/ Filter position with bed file
# ## 3/ Split sample from vcf
# ## 4/ Filter read depth (min_base_count = 10) and maybe ref, alt
# ## 5/ Annotation with exomiser
# ## 6/ Filter function_class (protein affecting) and maybe freq
# ## 7/ Merge results
# ## 8/ Preprocessing and Burden test
# ## 9/ Output report

# %%
# import cell
import subprocess
import os
import fileinput
import sys

import pandas as pd
import numpy as np
from pysam import VariantFile as psVa

# %% [markdown]
# ## ============= Modify these parameters ====================

# %%
# folder containing all input: vcf, bedfile, correspondance_table, exome file
input_path = "/data/BurdenTest/Lithiasis_mar/"

# vcf and input file name. All input files must be in input folder
vcf_name = "Lithiasis_set_20082018-123-samples.vcf"
bedfile = "BED_Letav-sorted.bed"
ctable = "Correspondance_table.tsv"
exomefile = "exome.yml"
genefile = input_path+"refFlat.txt.gz"

# Tool path: 
exom_path = "/home/phung/Documents/work/exomiser/exomiser_cli_8/exomiser-cli-8.0.0.jar"
rvtest_pwd = "/home/phung/rvtests/executable/rvtest"

# %% [markdown]
# ## ============= Run cells and do not modify ====================

# %%
output = input_path+"output"
out_data = output + "/data"
out_exome = output + "/exome"
out_rvtest = output + "/rvtest"
out_report = output +"/report"
os.system("mkdir "+output)
os.system("mkdir "+out_data)
os.system("mkdir "+out_exome)
os.system("mkdir "+out_rvtest)
os.system("mkdir "+out_report)
print "***** For output folders ", output
# Out:
# ***** For output folders  /data/BurdenTest/Lithiasis_mar/output

# %%
input_vcf = input_path + vcf_name
input_bed = input_path + bedfile
input_table = input_path + ctable
input_exome = input_path + exomefile

# %%
name = vcf_name[0:len(vcf_name)-4]

# %% [markdown]
# # 1/ Review input data

# %%
a = subprocess.check_output("grep -v '^#' "+input_vcf+" | cut -f 1 | sort", shell = True)
print "Number of variants (base pairs): \n", a.count('\n')
# Out:
# Number of variants (base pairs):
# 13280

# %%
a = subprocess.check_output("grep -v '^#' "+input_vcf+" | cut -f 1 | sort | uniq -c", shell = True)
print "Number of chrome: \n", a.count('\n')
print "Number of variants in each chrome: \n", a
# Out:
# Number of chrome:
# 18
# Number of variants in each chrome:
#     878 1
#     584 10
#     694 11
#     836 12
#     766 13
#    1057 16
#     424 19
#     363 2
#     267 20
#     324 21
#     778 3
#     598 4
#     870 5
#     796 6
#     844 7
#     694 8
#    1846 9
#     661 X

# %%
# 0   1  165370159  165414433   -1
# 1   1   43198764   43205925   -1
# 2   1  156211753  156213112    1
# 3  10   97471536   97637023    1
# 4  10   75668935   75677255    1

# %%
vcf_bedfil = out_data + '/' + name + '_filterposition.vcf'
cmn = "bedtools intersect -a " + input_vcf + " -b " + input_bed + " -header > " + vcf_bedfil
print subprocess.check_output(cmn, shell = True)
print "***** Filter position with bedtools. Output is ", vcf_bedfil
# Out:
# ***** Filter position with bedtools. Output is  /data/BurdenTest/Lithiasis_mar/output/data/Lithiasis_set_20082018-123-samples_filterposition.vcf

# %%
# check number of variants after filter position 
a = subprocess.check_output("grep -v '^#' "+ vcf_bedfil +" | cut -f 1 | sort", shell = True)
print "Number of variants after filtering positions: ", a.count('\n')
# Out:
# Number of variants after filtering positions:  13211

# %%
a = subprocess.check_output("grep -v '^#' "+ vcf_bedfil +" | cut -f 1 | sort | uniq -c", shell = True)
print "Number of chrome: \n", a.count('\n')
print "Number of variants(Snps) in each chrome: \n", a
# Out:
# Number of chrome:
# 18
# Number of variants(Snps) in each chrome:
#     871 1
#     584 10
#     694 11
#     836 12
#     766 13
#    1057 16
#     424 19
#     363 2
#     267 20
#     324 21
#     775 3
#     596 4
#     861 5
#     748 6
#     844 7
#     694 8
#    1846 9
#     661 X

# %%
## delete ##contig lines created by position filter. If not, it's false when running exomiser

ffinput = fileinput.input(vcf_bedfil, inplace=1)

for i, line in enumerate(ffinput):
    if line[0:8] == "##contig":
        newline = "" 
    else: newline = line

    sys.stdout.write(newline)

ffinput.close()

# %% [markdown]
# # 3/ Split sample, Extract sample from multi-sample vcf
#     To run exomiser, we have to split vcf file to be single-sample vcf

# %%
# %%time
# use vcftools to extract sample so it must have bgzip and tabix files


print "***** Sort, zip, tabix file: ", vcf_bedfil
out_sort = vcf_bedfil[0:len(vcf_bedfil)-4] + "_sort.vcf"
bzip = out_sort + ".gz"
comm1 = "vcf-sort " + vcf_bedfil + " > " + out_sort
comm2 = "bgzip -c " + out_sort + " > " + bzip
comm3 = "tabix -p vcf " + bzip
subprocess.check_output(comm1, shell = True)
subprocess.check_output(comm2, shell = True)
subprocess.check_output(comm3, shell = True)
# Out:
# ***** Sort, zip, tabix file:  /data/BurdenTest/Lithiasis_mar/output/data/Lithiasis_set_20082018-123-samples_filterposition.vcf
# CPU times: user 1.47 ms, sys: 9.04 ms, total: 10.5 ms
# Wall time: 3.82 s

# %%
# %%time

print "***** Split samples ..."
for k in range(len(l_samples)):
    # monitor the process:
    sys.stdout.write('\r') 
    sys.stdout.write("[%-20s] %d/%d" % ('='*(1+k*20/len(l_samples)), k+1,len(l_samples)))
    sys.stdout.flush()
    
    comm = "vcf-subset -c " + l_samples[k] + " " + bzip + " > " + vcf_bedfil[0:len(vcf_bedfil)-4] + "_s" + str(k+1) + ".vcf"
    subprocess.check_output(comm, shell = True)
print "***** Done."
# Out:
# ***** Split samples ...
# [====================] 123/123***** Done.
# CPU times: user 236 ms, sys: 459 ms, total: 695 ms
# Wall time: 5min 32s

# %% [markdown]
# # 4/ Filter read depth (min_depth = 10, max_depth = 500)

# %%
def filter_DP(file_vcf):
    vcf_out = file_vcf[0:len(file_vcf)-4] + "_DP.vcf"
    f_in = open(file_vcf)
    F_OUT = open(vcf_out, "wb")

    read = f_in.readline()

    while read:
        newline = read
        if "#" not in read[0]:
            row = newline.split("\t")
            l_col = len(row)

            if l_col>7:

                tmp_samp = row[l_col-1].split(":")
                if len(tmp_samp[2]) == 1: # less than 10
                    newline = ""
                else:
                    if int(tmp_samp[2]) > 500:
                        newline = ""


        F_OUT.write(newline)       
        read = f_in.readline()


    f_in.close()
    F_OUT.close()

# %%
# %%time
print "***** Running filter read depth ..."
for k in range(len(l_samples)):
    file_vcf = vcf_bedfil[0:len(vcf_bedfil)-4] + "_s" + str(k+1) + ".vcf"
    filter_DP(file_vcf)
print "***** Done."
# Out:
# ***** Running filter read depth ...
# ***** Done.
# CPU times: user 12.3 s, sys: 1.76 s, total: 14 s
# Wall time: 14.3 s

# %%
print "***** File name after filter read depth: ", vcf_bedfil[0:len(vcf_bedfil)-4] + "_s" + str(1) + "_DP.vcf"
# Out:
# ***** File name after filter read depth:  /data/BurdenTest/Lithiasis_mar/output/data/Lithiasis_set_20082018-123-samples_filterposition_s1_DP.vcf

# %% [markdown]
# # 5/ Annotation with Exomiser

# %%
out_exome_conf = out_exome + "/conf"
out_exome_result = out_exome + "/result"
os.system("mkdir "+out_exome_conf)
os.system("mkdir "+out_exome_result)
# Out:
# 0

# %%
print "***** Generate conf files for running EXOMISER in ", out_exome_conf
for k in range(len(l_samples)):
    #print "sample:", k+1
    file_yml = out_exome_conf + "/exome_s" + str(k+1) + ".yml"
    os.system("cp " + input_exome + " " + file_yml)

    finput = fileinput.input(file_yml, inplace=1)
    file_vcf = vcf_bedfil[0:len(vcf_bedfil)-4] + "_s" + str(k+1) + "_DP.vcf"
    file_result = out_exome_result + '/'+name + "_exome_s" + str(k+1)
    
    for i, line in enumerate(finput):
        newline = line.replace("dataname", file_vcf)
        newline = newline.replace("resultname", file_result)
        sys.stdout.write(newline)
        
    finput.close()
print "***** Output this part will be in ", out_exome_result
# Out:
# ***** Generate conf files for running EXOMISER in  /data/BurdenTest/Lithiasis_mar/output/exome/conf
# ***** Output this part will be in  /data/BurdenTest/Lithiasis_mar/output/exome/result

# %%
# %%time
print "***** Annotation by EXOMISER *****"
for k in range(len(l_samples)):
    # monitor the process:
    sys.stdout.write('\r') 
    sys.stdout.write("[%-20s] %d/%d" % ('='*(1+k*20/len(l_samples)), k+1,len(l_samples)))
    sys.stdout.flush()
    
    file_yml = out_exome_conf + "/exome_s" + str(k+1) + ".yml"
    comm = "time java -Xms2g -Xmx10g -jar " + exom_path + " --analysis " + file_yml
    
    subprocess.check_output(comm, shell = True)
# Out:
# ***** Annotation by EXOMISER *****
# [====================] 123/123CPU times: user 310 ms, sys: 508 ms, total: 817 ms
# Wall time: 19min 40s

# %% [markdown]
# # 6/ Filter function_class (protein affecting) and maybe freq

# %%
af_pro = ["missense_variant", "splice_region_variant", "stop_gained", "frameshift_variant", "stop_lost", "inframe_deletion", "inframe_insertion"] 
print "***** Filter genes with protein affecting: ", af_pro
def filter_fc(file_va, file_vcf):
    df_va = pd.read_csv(file_va, sep = "\t")
    df_tmp = df_va[df_va.FUNCTIONAL_CLASS.isin(af_pro)]
    pos = list(df_tmp.POS)

    os.system("cp " + file_vcf + " " + file_vcf[0:len(file_vcf)-4] + "_fc.vcf")
    tmp = file_vcf[0:len(file_vcf)-4] + "_fc.vcf"
    tmpinput = fileinput.input(tmp, inplace=1)
    for i, line in enumerate(tmpinput):
        a = line.split("\t")
        if len(a)>3:
            if a[1] == "POS": newline = line
            else: 
                if int(a[1]) in pos: newline = line
                else: newline = ""

        else: 
            newline = line
        sys.stdout.write(newline)


            #sys.stderr.write(line +'\n')
    tmpinput.close()
# Out:
# ***** Filter genes with protein affecting:  ['missense_variant', 'splice_region_variant', 'stop_gained', 'frameshift_variant', 'stop_lost', 'inframe_deletion', 'inframe_insertion']

# %%
# %%time
for k in range(len(l_samples)):
    file_va = out_exome_result + '/'+name + "_exome_s" + str(k+1) + ".variants.tsv"
    file_vcf = out_exome_result + '/'+name + "_exome_s" + str(k+1) + ".vcf"
    filter_fc(file_va, file_vcf)

print "Output file name: ", out_exome_result + '/'+name + "_exome_s" + str(1) + "_fc.vcf"
# Out:
# Output file name:  /data/BurdenTest/Lithiasis_mar/output/exome/result/Lithiasis_set_20082018-123-samples_exome_s1_fc.vcf
# CPU times: user 1.26 s, sys: 351 ms, total: 1.61 s
# Wall time: 2.32 s

# %% [markdown]
# # 7/ Merge results

# %%
# %%time
# Merge vcf results
vcf_merge = out_exome + '/' +name + "_merge_exomiser_all.vcf"
# sort and bzip files
for k in range(len(l_samples)):
    result = out_exome_result + '/'+name + "_exome_s" + str(k+1) + ".vcf"
    out_sort = out_exome_result + '/'+name + "_exome_sort_s" + str(k+1)+".vcf"
    bzip = out_exome_result + '/'+name + "_exome_bz_s" + str(k+1)+ ".vcf.gz"
    
    comm1 = "vcf-sort " + result + " > " + out_sort
    comm2 = "bgzip -c " + out_sort + " > " + bzip
    comm3 =  "tabix -p vcf " + bzip
    subprocess.check_output(comm1, shell = True)
    subprocess.check_output(comm2, shell = True)
    subprocess.check_output(comm3, shell = True)
comm4 = "vcf-merge"

for k in range(len(l_samples)):
    bzip = " " + out_exome_result + '/'+name + "_exome_bz_s" + str(k+1)+ ".vcf.gz"
    comm4 = comm4 + bzip
comm4 = comm4 + " > " + vcf_merge
print subprocess.check_output(comm4, shell = True)   

print "***** Merge results of exomiser. Output is ", vcf_merge
# Out:
# ***** Merge results of exomiser. Output is  /data/BurdenTest/Lithiasis_mar/output/exome/Lithiasis_set_20082018-123-samples_merge_exomiser_all.vcf
# CPU times: user 88 ms, sys: 1.26 s, total: 1.35 s
# Wall time: 42.1 s

# %%
# check number of variants after merging

a = subprocess.check_output("grep -v '^#' "+ vcf_merge +" | cut -f 1 | sort", shell = True)
print "Number of variants after merging: ", a.count('\n')
# Out:
# Number of variants after merging:  5770

# %% [markdown]
# # 8/ Preprocessing and Burden test
#
#     Input to run rvtest-burden test:
#             - vcf file with genetype of all patients
#             - pheno file: phenotype of all patients
#             - genefile: mapping position with gene-names

# %% [markdown]
# ## 8.1/ Prepare input

# %%
# remove header
print "***** Remove header ", vcf_merge
mfile = vcf_merge
os.system("cp " + mfile + " " + mfile[0:len(mfile)-4] + "_1.vcf")
mfile = mfile[0:len(mfile)-4] + "_1.vcf"
minput = fileinput.input(mfile, inplace=1)

for i, line in enumerate(minput):
    if line[0:2] == "##":
        newline = ""
    else: newline = line
    
    sys.stdout.write(newline)
minput.close()
print "***** Output is ", mfile
# Out:
# ***** Remove header  /data/BurdenTest/Lithiasis_mar/output/exome/Lithiasis_set_20082018-123-samples_merge_exomiser_all.vcf
# ***** Output is  /data/BurdenTest/Lithiasis_mar/output/exome/Lithiasis_set_20082018-123-samples_merge_exomiser_all_1.vcf

# %%
def findchar(s, ch):
    return [i for i, ltr in enumerate(s) if ltr == ch]

# %%
# edit values, keep GT 1/1, 0/1 or 0/0
print "***** Edit values, keep Genetype 1/1, 0/1 or 0/0"
mfile = mfile[0:len(mfile)-6] + "_1.vcf"
os.system("cp " + mfile + " " + mfile[0:len(mfile)-6] + "_2.vcf")
mfile = mfile[0:len(mfile)-6] + "_2.vcf"
minput = fileinput.input(mfile, inplace=1)

for i, line in enumerate(minput):
    #sys.stderr.write(line +'\n')
    newline = line
    at1 = findchar(newline,"\t")
    line1 = newline[at1[8]+1:len(newline)]
    line1 = line1.replace("./", "0/")
    line1 = line1.replace("/.", "/1")
    line1 = line1.replace(".", "0/0")
    ac1 = findchar(line1,":")
    while len(ac1)>1:
        at2 = findchar(line1[ac1[0]:len(line1)],"\t")
        if len(at2)>0:
            line1 = line1.replace(line1[ac1[0]:ac1[0]+at2[0]], "")
        else:
            line1 = line1.replace(line1[ac1[0]:len(line1)], "\n")

        ac1 = findchar(line1,":")
        
    newline = newline[0:at1[8]+1] + line1
    sys.stdout.write(newline)
minput.close()
print "***** Output is ", mfile
# Out:
# ***** Edit values, keep Genetype 1/1, 0/1 or 0/0
# ***** Output is  /data/BurdenTest/Lithiasis_mar/output/exome/Lithiasis_set_20082018-123-samples_merge_exomiser_all_2.vcf

# %%
# bgzip and tabix files for burden test using rvtest
result = mfile
out_sort = mfile[0:len(mfile)-6] + "_sort.vcf"
bzip = out_sort[0:len(out_sort)-4] + "_bz.vcf.gz"
comm1 = "vcf-sort " + mfile + " > " + out_sort
comm2 = "bgzip -c " + out_sort + " > " + bzip
comm3 =  "tabix -p vcf " + bzip
subprocess.check_output(comm1, shell = True)
subprocess.check_output(comm2, shell = True)
subprocess.check_output(comm3, shell = True)
print "***** Sort, zip, tabix file vcf to make input for burden test: ", bzip
# Out:
# ***** Sort, zip, tabix file vcf to make input for burden test:  /data/BurdenTest/Lithiasis_mar/output/exome/Lithiasis_set_20082018-123-samples_merge_exomiser_all_sort_bz.vcf.gz

# %% [markdown]
# ## 8.2/ Prepare phenotype values for burden test
#
# extract samples ID in df_tab, then compare with ID 1 in df_bio to get values

# %% [markdown]
# ### ===== View table and Check the correspondence table =====

# %%
df_tab = pd.read_csv(input_table, sep = "\t")

# %%
df_tab.head()
# Out:
#                                #HASH-ID SAMPLE-Number  \
# 0  23117b5d-6580-4d23-9b4d-d33f05d51304            p1
# 1  33d41660-b7f6-455b-a8fa-b71e138c5284            p2
# 2  53f34b70-a595-4851-b097-b09a3b9bfb3f            p3
# 3  48006d66-7118-4cdf-a58f-aed98c7d10c0            p4
# 4  e2509c87-a435-4d80-976b-af5163283915            p5
#
#                                      SAMPLES-NAMES
# 0  LABDO-F-48-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# 1   BERT-M-62-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 2    JAM-M-24-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 3   FRIT-M-45-PLq0-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH1
# 4   CHAP-F-39-PLq1-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH1

# %%
flag = 0
for i in l_samples:
    if i not in list(df_tab["#HASH-ID"]):
        print i
        flag = flag + 1
if flag == 0:
    print "All samples are in the table."
else:
    print "Above samples are not in the table"
# Out:
# All samples are in the table.

# %%
df_tab
# Out:
#                                  #HASH-ID SAMPLE-Number  \
# 0    23117b5d-6580-4d23-9b4d-d33f05d51304            p1
# 1    33d41660-b7f6-455b-a8fa-b71e138c5284            p2
# 2    53f34b70-a595-4851-b097-b09a3b9bfb3f            p3
# 3    48006d66-7118-4cdf-a58f-aed98c7d10c0            p4
# 4    e2509c87-a435-4d80-976b-af5163283915            p5
# 5    c637f3f6-51a1-48ea-ab3d-d4b4d0505000            p6
# 6    cfa73cf1-ece8-43d2-bcb3-c246c4125a2e            p7
# 7    38b36697-30b7-48c4-9f12-3f584af3627b            p8
# 8    255121b7-e79d-438e-b96a-1445ed3fb826            p9
# 9    95fc3f50-daa0-4268-ae0e-3e21851afb72           p10
# 10   27e48e34-d260-4a1b-a46f-a54d930e0eb6           p11
# 11   a8d27700-c1f6-4cc8-a9c3-d42efe17cfc9           p12
# 12   8dca9d54-79fc-4ebf-84ce-abacf8a7d222           p13
# 13   fa4cc852-77f8-414f-b5d6-a9d93f7bde27           p14
# 14   1f6e253e-4a32-4145-9df4-b98ded65d82b           p15
# 15   895840c1-6479-4d2a-bf91-7b3b781da157           p16
# 16   f8febc29-e42d-4f6c-9fc3-b1ed77326921           p17
# 17   7f548358-3644-4350-9b20-bf67dbc6dc08           p18
# 18   364d4299-8a5d-4e7f-8fc3-7396039f34a3           p19
# 19   45725c22-88c2-4c6b-982e-6908f576fcc5           p20
# 20   bcbeb870-7f1c-4920-a150-9b2191456d3d           p21
# 21   e540b4d1-e8ae-467a-930f-cd9a1f95549e           p22
# 22   2bc926dd-710c-4844-af85-3428bbf46fea           p23
# 23   d3f33f15-57d9-44c2-a738-f6e8ec853b7a           p24
# 24   73db0960-83be-43b9-9810-c4ed28eae64c           p25
# 25   a5762944-a1b5-4cf3-9b04-046951fd8ddc           p26
HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0
# 17        53-F-56-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0
# 18        59-M-41-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 19       MOR-M-70-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 20      BOUC-F-82-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# 21       OKS-F-53-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 22      LEST-M-44-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 23     DOUZ-M-48-PLq0-HOXnd-HCaLciU1-HCt3oL0-RCt3oLOH1
# 24         3-M-31-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH1
# 25        86-M-67-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 26    PLANQ -M-62-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH1
# 27      CHAU-F-39-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH1
# 28       MAT-M-57-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 29      MART-M-66-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# ..                                                 ...
# 93        52-M-40-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0
# 94     CROZE-F-69-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 95      PERS-M-35-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0
# 96      LEVY-M-52-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 97      89-M-40-PLq0-HOXnd-HCaLciU1-HCt3oL1-RCt3oLOHnd
# 98       DER-F-56-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH1
# 99      LABO-M-67-PLq0-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0
# 100     POUR-F-48-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 101     LIGO-M-53-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 102       97-M-54-PLq0-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH1
# 103   DOMINE-M-59-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 104     MARD-M-47-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# 105     SOUS-M-69-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH1
# 106     SAIN-M-39-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 107       90-F-51-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 108   FRANCK-M-52-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH0
# 109      MKH-M-50-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH1
# 110     TANE-M-60-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# 111      LES-F-65-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0
# 112       55-F-56-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0
# 113   GRUBER-M-70-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0
# 114      SUN-M-62-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1
# 115      BER-F-63-PLq0-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH1
# 116     RAFF-F-29-PLq1-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH0
# 117      DOG-M-57-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH1
# 118       56-M-42-PLq1-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH0
# 119     GUAL-M-70-PLq0-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH1
# 120     BAC-M-59-PLq0-HOXnd-HCaLciU1-HCt3oL0-RCt3oLOH1
# 121  CARR-M-95-PLq0-HOXnd-HCaLciUnd-HCt3oLnd-RCt3oL...
# 122       58-F-49-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0
#
# [123 rows x 3 columns]

# %%
def pheno_binary(idx1, idx2, phenoname):
    plq = []
    for i in range(len(df_tab)):
        tmp = df_tab["SAMPLES-NAMES"][i].split("-")
        if tmp[idx1][idx2] != 'n':
            plq.append(tmp[idx1][idx2])
        else: 
            plq.append('nd')
    df_tab[phenoname] = plq

# %%
pheno_binary(3, 3, "PLq")
pheno_binary(4, 3, "HOX")
pheno_binary(5, 7, "HCaLciU")
pheno_binary(6, 6, "HCt3oL")
pheno_binary(7, 8, "RCt3oLOH")

# %%
df_tab
# Out:
#                                  #HASH-ID SAMPLE-Number  \
# 0    23117b5d-6580-4d23-9b4d-d33f05d51304            p1
# 1    33d41660-b7f6-455b-a8fa-b71e138c5284            p2
# 2    53f34b70-a595-4851-b097-b09a3b9bfb3f            p3
# 3    48006d66-7118-4cdf-a58f-aed98c7d10c0            p4
# 4    e2509c87-a435-4d80-976b-af5163283915            p5
# 5    c637f3f6-51a1-48ea-ab3d-d4b4d0505000            p6
# 6    cfa73cf1-ece8-43d2-bcb3-c246c4125a2e            p7
# 7    38b36697-30b7-48c4-9f12-3f584af3627b            p8
# 8    255121b7-e79d-438e-b96a-1445ed3fb826            p9
# 116  981436f2-8ccb-4f4e-b961-bb14d1197d80          p117
# 117  d120bfd2-c0ee-4ec7-a0fe-4f92b55f7437          p118
# 118  e6d4f4b0-cf4e-4236-a1f4-285311b2df47          p119
# 119  1f74aa26-c6e1-4642-b453-836a0a32c784          p120
# 120  0c08197c-360c-4e92-8aa3-05eb850fa0db          p121
# 121  0dfb23a0-2a65-4e50-bad5-11f036ae8ef5          p122
# 122  700b0b2b-e53a-4e3a-b08f-b43ce27d36d5          p123
#
#                                          SAMPLES-NAMES PLq HOX HCaLciU HCt3oL  \
# 0      LABDO-F-48-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   0   0       0      0
# 1       BERT-M-62-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   0   0       0      0
# 2        JAM-M-24-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   0   0       1      0
# 3       FRIT-M-45-PLq0-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH1   0   0       0      1
# 4       CHAP-F-39-PLq1-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH1   1   0       1      1
# 5         87-M-65-PLq0-HOX1-HCaLciU0-HCt3oL1-RCt3oLOH1   0   1       0      1
# 6      LEJEU-M-69-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 7       BLON-M-36-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   0   0       0      0
# 8        JOL-M-83-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   0   0       0      0
# 9       GUER-M-60-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH1   0   0       1      0
# 10     BOUCE-M-50-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   1   0       0      0
# 11        57-M-59-PLq1-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH0   1   1       1      0
# 12       MAB-M-67-PLq0-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH1   0   0       1      1
# 13      BOIT-M-52-PLq0-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH0   0   0       1      1
# 14       LAM-M-41-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0   1   1       0      0
# 15   LACH-F-52-PLq1-HOXnd-HCaLciUnd-HCt3oLnd-RCt3oL...   1  nd      nd     nd
# 16      LEFR-M-61-PLq0-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0   0   1       0      0
# 17        53-F-56-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0   1   1       0      0
# 18        59-M-41-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   1   0       0      0
# 19       MOR-M-70-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   0   0       1      0
# 20      BOUC-F-82-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   0   0       0      0
# 21       OKS-F-53-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   1   0       0      0
# 22      LEST-M-44-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   0   0       1      0
# 23     DOUZ-M-48-PLq0-HOXnd-HCaLciU1-HCt3oL0-RCt3oLOH1   0  nd       1      0
# 24         3-M-31-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH1   1   0       1      0
# 25        86-M-67-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   0   0       0      0
# 26    PLANQ -M-62-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH1   1   0       0      1
# 27      CHAU-F-39-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH1   1   1       0      0
# 28       MAT-M-57-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 29      MART-M-66-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   0   0       0      0
# ..                                                 ...  ..  ..     ...    ...
# 93        52-M-40-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0   1   0       0      1
# 94     CROZE-F-69-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 95      PERS-M-35-PLq1-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0   1   0       0      1
# 96      LEVY-M-52-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   1   0       0      0
# 97      89-M-40-PLq0-HOXnd-HCaLciU1-HCt3oL1-RCt3oLOHnd   0  nd       1      1
# 98       DER-F-56-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH1   0   1       1      1
# 99      LABO-M-67-PLq0-HOX0-HCaLciU0-HCt3oL1-RCt3oLOH0   0   0       0      1
# 100     POUR-F-48-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   1   0       0      0
# 101     LIGO-M-53-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 102       97-M-54-PLq0-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH1   0   1       1      0
# 103   DOMINE-M-59-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 104     MARD-M-47-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   1   0       0      0
# 105     SOUS-M-69-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH1   1   1       0      0
# 106     SAIN-M-39-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 107       90-F-51-PLq0-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   0   0       0      0
# 108   FRANCK-M-52-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH0   0   1       1      1
# 109      MKH-M-50-PLq0-HOX1-HCaLciU1-HCt3oL1-RCt3oLOH1   0   1       1      1
# 110     TANE-M-60-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   1   0       0      0
# 111      LES-F-65-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH0   1   0       0      0
# 112       55-F-56-PLq1-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH0   1   0       1      0
# 113   GRUBER-M-70-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0   1   1       0      0
# 114      SUN-M-62-PLq1-HOX0-HCaLciU0-HCt3oL0-RCt3oLOH1   1   0       0      0
# 115      BER-F-63-PLq0-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH1   0   1       1      0
# 116     RAFF-F-29-PLq1-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH0   1   0       1      1
# 117      DOG-M-57-PLq0-HOX0-HCaLciU1-HCt3oL0-RCt3oLOH1   0   0       1      0
# 118       56-M-42-PLq1-HOX1-HCaLciU1-HCt3oL0-RCt3oLOH0   1   1       1      0
# 119     GUAL-M-70-PLq0-HOX0-HCaLciU1-HCt3oL1-RCt3oLOH1   0   0       1      1
# 120     BAC-M-59-PLq0-HOXnd-HCaLciU1-HCt3oL0-RCt3oLOH1   0  nd       1      0
# 121  CARR-M-95-PLq0-HOXnd-HCaLciUnd-HCt3oLnd-RCt3oL...   0  nd      nd     nd
# 122       58-F-49-PLq1-HOX1-HCaLciU0-HCt3oL0-RCt3oLOH0   1   1       0      0
#
#     RCt3oLOH
# 0          1
# 1          0
# 2          0
# 3          1
# 4          1
# 5          1
# 6          0
# 7          1
# 8          1
# 9          1
# 10         1
# 11         0
# 12         1
# 13         0
# 14         0
# 15        nd
# 16         0
# 17         0
# 18         0
# 19         0
# 20         1
# 21         0
# 22         0
# 23         1
# 24         1
# 25         0
# 26         1
# 27         1
# 28         0
# 29         1
# ..       ...
# 93         0
# 94         0
# 95         0
# 96         0
# 97        nd
# 98         1
# 99         0
# 100        0
# 101        0
# 102        1
# 103        0
# 104        1
# 105        1
# 106        0
# 107        0
# 108        0
# 109        1
# 110        1
# 111        0
# 112        0
# 113        0
# 114        1
# 115        1
# 116        0
# 117        1
# 118        0
# 119        1
# 120        1
# 121       nd
# 122        0
#
# [123 rows x 8 columns]

# %% [markdown]
# ### ===== Make phenotype file using df_tab =====

# %%
out_pheno = out_rvtest + "/pheno"
out_burden = out_rvtest + "/burden"
out_burden_gene = out_rvtest + "/burden_gene"
os.system("mkdir "+ out_burden_gene)
os.system("mkdir "+ out_pheno)
os.system("mkdir "+ out_burden)
# Out:
# 0

# %%
def phenofile_binary(phenoname):
    f = open(out_pheno + '/pheno_' + phenoname,'wb')
    f.write("fid iid fatid matid sex y1\n")

    for k in range(len(df_tab)):
        name = df_tab["#HASH-ID"][k]


        if df_tab[phenoname][k][0] != 'n':
            f.write(name + " " + name + " 0 0 0 " + df_tab[phenoname][k] + "\n")
        else:
            f.write(name + " " + name + " 0 0 0 0\n")

    f.close()

# %%
phenofile_binary("PLq")
phenofile_binary("HOX")
phenofile_binary("HCaLciU")
phenofile_binary("HCt3oL")
phenofile_binary("RCt3oLOH")

# %% [markdown]
# ## 8.3/ Burden normal with genefile refFlat.txt.gz
# https://genome.sph.umich.edu/wiki/Rvtests

# %% [markdown]
# ### 8.3.1/ Burden normal with only a genename

# %%
def rvtest_gene(phenoname, gene):
    #shell1 = "if [ ! -d 'rvtest/" +phenotype+ "' ]; then\n\t" + "mkdir rvtest/" + phenotype + "\nfi" 
    #print subprocess.check_output(shell1, shell = True)
    
    invcf = bzip
    pheno = out_pheno + '/pheno_' + phenoname
    
    outrv = out_burden_gene + "/output_"+phenoname+"_"+gene
    model = "zeggini"
    
    comm = rvtest_pwd + " --inVcf " + invcf + " --pheno " + pheno + " --qtl "  + " --geneFile "+ genefile + " --gene " + gene + " --out " + outrv + " --burden "+model
    print subprocess.check_output(comm, shell = True)

# %% [markdown]
# ### ================== Modify this part for running burdentest function ===============
#     - rvtest_gene(phenoname, gene)
#     - phenoname: PLq, HOX, HCaLciU, HCt3oL, RCt3oLOH
#     - gene: name of gene

# %%
print "***** Burden test with some genes"
rvtest_gene("PLq","ABCC6")
# Out:
# ***** Burden test with some genes
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully

# %% [markdown]
# ### =====================================================================

# %% [markdown]
# ### 8.3.2/ Burden test with all available genes

# %%
def rvtest(phenoname):

    invcf = bzip
    pheno = out_pheno + '/pheno_' + phenoname
    
    outrv = out_burden + "/output_"+phenoname
    model = "zeggini"
    comm = rvtest_pwd + " --inVcf " + invcf + " --pheno " + pheno  + " --qtl " + " --geneFile " + genefile + " --out " + outrv + " --burden "+ model
    print subprocess.check_output(comm, shell = True)

# %%
# %%time
rvtest("PLq")
rvtest("HOX")
rvtest("HCaLciU")
rvtest("HCt3oL")
rvtest("RCt3oLOH")
# Out:
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully
#
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully
#
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully
#
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully
#
# Thank you for using rvtests (version: 20171009, git: 02a02ba9f5927aee3df3b8162efed8e23aaea886)
#   For documentations, refer to http://zhanxw.github.io/rvtests/
#   For questions and comments, send to Xiaowei Zhan <zhanxw@umich.edu>
#   For bugs and feature requests, please submit at: https://github.com/zhanxw/rvtests/issues
#
# RVTESTS finished successfully
#
# CPU times: user 7.23 ms, sys: 20.9 ms, total: 28.2 ms
# Wall time: 4.61 s

# %% [markdown]
# # 9/ Output report

# %%
file_list = []
for file in os.listdir(out_burden):
    if file.endswith(".assoc"):
        a = os.path.join(out_burden, file)
        file_list.append(a)

# %%
file_list
# Out:
# ['/data/BurdenTest/Lithiasis_mar/output/rvtest/burden/output_HCaLciU.Zeggini.assoc',
#  '/data/BurdenTest/Lithiasis_mar/output/rvtest/burden/output_RCt3oLOH.Zeggini.assoc',
#  '/data/BurdenTest/Lithiasis_mar/output/rvtest/burden/output_HCt3oL.Zeggini.assoc',
#  '/data/BurdenTest/Lithiasis_mar/output/rvtest/burden/output_HOX.Zeggini.assoc',
#  '/data/BurdenTest/Lithiasis_mar/output/rvtest/burden/output_PLq.Zeggini.assoc']

# %%
n = len(file_list)
#df = pd.DataFrame()
for i in range(len(file_list)):
    a = file_list[i].split('/')
    b = a[len(a)-1].split('.')
    dftmp = pd.read_csv(file_list[i], sep='\t')
    if i == 0:
        df = dftmp
        df = df.rename(columns={"Pvalue": b[0]})
    else:
        df[b[0]] = dftmp["Pvalue"]

# %%
df
# Out:
#             Gene                                              RANGE  \
# 0           IDUA                    4:980784-998345,4:980784-998345
# 1           AQP1            7:30951308-30965132,7:30951308-30965132
# 2          HOGA1          10:99344101-99372555,10:99344101-99372555
# 3          TRPV6                              7:142568955-142583490
# 4           DGKH  13:42712177-42830716,13:42712177-42817033,13:4...
# 5         ENTPD1  10:97515672-97637023,10:97515408-97637023,10:9...
# 6          FGFR1  8:38268655-38326352,8:38268655-38325363,8:3826...
# 7     PMF1-BGLAP  1:156182778-156213123,1:156182778-156213123,1:...
# 8        SLC26A7  8:92261515-92406946,8:92221721-92410382,8:9226...
# 9          AP2S1  19:47341414-47354252,19:47341414-47354252,19:4...
# 10          NT5E            6:86159301-86205509,6:86159301-86205509
# 11          LDHA  11:18415935-18429765,11:18415935-18429765,11:1...
# 12      C10orf55                               10:75669726-75682535
# 13        CLDN19  1:43198763-43205925,1:43198763-43205925,1:4319...
# 14    ENTPD1-AS1  10:97512962-97849992,10:97780956-97849992,10:9...
# 15          OCRL  X:128674231-128726537,X:128674251-128726530,X:...
# 16          RXRG  1:165406164-165414592,1:165370158-165394221,1:...
# 17         ABCC6  16:16243421-16317328,16:16315043-16317328,16:1...
# 18          RXRA  9:137271140-137332432,9:137218308-137332432,9:...
# 19          ALPL  1:21835850-21904905,1:21835850-21904905,1:2183...
# 20        CLDN14  21:37832919-37852388,21:37832919-37915117,21:3...
# 21         CLCN5  X:49687224-49863892,X:49687224-49863892,X:4983...
# 22       SLC26A1    4:981444-987228,4:972860-987228,4:981444-987228
# 23          SPP1  4:88896801-88904563,4:88896801-88904563,4:8889...
# 24       SLC34A1        5:176811431-176817514,5:176811431-176825849
# 25          UMOD  16:20344372-20364200,16:20344372-20364200,16:2...
# 26       SLC26A6  3:48663155-48672926,3:48663155-48672926,3:4866...
# 27          RXRB  6_qbl_hap6:4393583-4400853,6_qbl_hap6:4393583-...
# 28       SLC34A3  9:140125208-140131006,9:140125384-140131006,9:...
# 29          ANKH                                5:14704908-14871894
# 30            KL                               13:33590570-33640282
# 31        CLDN16                              3:190105660-190129932
# 32          DMP1            4:88571453-88585512,4:88571453-88585512
# 33            F2          11:46740715-46761058,11:46740715-46761058
# 34         FGF23                                 12:4477392-4488894
# 35          PLAU  10:75670858-75677258,10:75670858-75677258,10:7...
# 36        MINDY4                                7:30811032-30932002
# 37         BGLAP                              1:156211752-156213123
# 38        LRRC69  8:92114846-92231482,8:92114846-92231464,8:9211...
# 39         ENPP1                              6:132129155-132216295
# 40       MIR6824                                3:48671068-48671131
# 41         GNA11                                 19:3094407-3124000
# 42  LOC100130744                                5:14712802-14716638
# 43       CYP24A1          20:52769987-52790516,20:52769987-52790516
# 44          AHSG  3:186330711-186339107,3:186330711-186339107,3:...
# 45          PHEX            X:22050561-22269427,X:22050561-22269427
# 46          CD44  11:35160416-35253949,11:35160416-35253949,11:3...
# 47   INMT-MINDY4                                7:30791750-30932002
# 48         TRPV5                              7:142605266-142630820
# 49           MGP          12:15033797-15038996,12:15033797-15038996
# 50      PHEX-AS1                                X:22180848-22191100
# 51     PTCHD1-AS                                X:22211121-23311263
# 52          CASR        3:121903180-122005344,3:121902529-122005344
# 53         GRHPR                                9:37422706-37436986
# 54           VDR  12:48235319-48298814,12:48235319-48298814,12:4...
# 55       CYP27B1                               12:58156116-58160976
# 56       SLC26A2                              5:149340299-149366963
# 57       SLC26A3                              7:107405911-107443678
# 58          AGXT                              2:241808161-241818536
#
#     N_INFORMATIVE  NumVar  NumPolyVar  output_HCaLciU  output_RCt3oLOH  \
# 0             123     237         237        0.182632         0.642384
# 1             123      72          72        0.063863         0.864033
# 2             123      87          87        0.789953         0.711489
# 3             123     104         104        0.942145         0.826887
# 4             123     203         203        0.059272         0.090897
# 5             123     123         122        0.275487         0.861010
# 6             123     196         196        0.961487         0.227380
# 7             123      35          35        0.085070         0.327529
# 8             123      71          71        0.373809         0.796463
# 9             123      60          60        0.651892         0.556676
# 10            123      74          74        0.008629         0.230534
# 11            123      64          64        0.025618         0.402324
# 12            123      59          59        0.200530         0.736812
# 13            123      96          96        0.182980         0.920239
# 14            123     106         105        0.213655         0.650802
# 15            123      99           0             NaN              NaN
# 16            123      96          96        0.008312         0.187734
# 17            123     350         350        0.708924         0.632437
# 18            123     543         543        0.352498         0.328504
# 19            123     185         185        0.353168         0.261914
# 20            123      99          99        0.056088         0.590657
# 21            123      80           0             NaN              NaN
# 22            123     242         242        0.162238         0.601207
# 23            123      30          30        0.050570         0.446517
# 24            123     130         130        0.265466         0.382148
# 25            123     120         120        0.035957         0.618962
# 26            123     122         122        0.259182         0.282250
# 27            123      86          86        0.108648         0.617611
# 28            123     214         214        0.921262         0.236195
# 29            123     136         136        0.502822         0.515237
# 30            123      85          85        0.491883         0.468394
# 31            123      31          31        0.680656         0.498577
# 32            123      22          22        0.551483         0.814106
# 33            123     106         106        0.774727         0.766066
# 34            123      41          41        0.025527         0.151520
# 35            123      58          58        0.216814         0.768583
# 36            123      45          45        0.928713         0.926546
# 37            123      35          35        0.085070         0.327529
# 38            123       5           5        0.078308         0.251795
# 39            123     155         155        0.184166         0.194444
# 40            123       1           1        0.358634         0.279939
# 41            123     112         112        0.137717         0.777367
# 42            123      26          26        0.954330         0.299236
# 43            123     135         135        0.878690         0.276131
# 44            123      64          64        0.134178         0.297647
# 45            123      82           0             NaN              NaN
# 46            123     142         142        0.431940         0.988627
# 47            123      45          45        0.928713         0.926546
# 48            123      94          94        0.484443         0.101120
# 49            123      29          29        0.477704         0.643285
# 50            123       4           0             NaN              NaN
# 51            123      30           0             NaN              NaN
# 52            123      88          88        0.431540         1.000000
# 53            123     107         107        0.130539         0.837060
# 54            123     142         142        0.150974         0.759974
# 55            123     104         104        0.834358         0.956849
# 56            123      54          54        0.914138         0.416262
# 57            123      84          83        0.747029         0.554510
# 58            123     182         182        0.765261         0.348487
#
#     output_HCt3oL  output_HOX  output_PLq
# 0        0.591938    0.641099    0.893561
# 1        0.336740    0.171602    0.730970
# 2        0.772668    0.428189    0.617054
# 3        0.981839    0.571667    0.388906
# 4        0.079103    0.966367    0.725966
# 5        0.057212    0.329341    0.786884
# 6        0.122125    0.922810    0.243967
# 7        0.977459    0.466477    0.342629
# 8        0.238820    0.149706    0.549599
# 9        0.901120    0.194529    0.486351
# 10       0.022849    0.419829    0.642006
# 11       0.903348    0.846581    0.586108
# 12       0.147664    0.189530    0.555079
# 13       0.421202    0.163072    0.599182
# 14       0.050506    0.391650    0.785660
# 15            NaN         NaN         NaN
# 16       0.193591    0.225716    0.305487
# 17       0.803726    0.082157    0.586244
# 18       0.873242    0.218170    0.365039
# 19       0.728289    0.336251    0.527368
# 20       0.316947    0.573772    0.434820
# 21            NaN         NaN         NaN
# 22       0.635425    0.640035    0.901569
# 23       0.720466    0.452203    0.746339
# 24       0.257671    0.950915    0.028551
# 25       0.905631    0.316446    0.754304
# 26       0.235661    0.386488    0.428928
# 27       0.030023    0.020811    0.823254
# 28       0.800659    0.815836    0.020924
# 29       0.826304    0.221825    0.140137
# 30       0.800427    0.416121    0.500162
# 31       0.180667    0.415735    0.206300
# 32       0.409354    0.056715    0.589101
# 33       0.159473    0.298886    0.334648
# 34       0.493943    0.816346    0.032005
# 35       0.142351    0.197460    0.584396
# 36       0.446724    0.611401    0.711513
# 37       0.977459    0.466477    0.342629
# 38       0.777413    0.318756    0.637222
# 39       0.271781    0.469387    0.119637
# 40       0.543183    0.603172    0.272079
# 41       0.725599    0.128258    0.645456
# 42       0.115523    0.520449    0.682185
# 43       0.903751    0.965947    0.328765
# 44       0.195179    0.875629    0.949772
# 45            NaN         NaN         NaN
# 46       0.486646    0.654617    0.449111
# 47       0.446724    0.611401    0.711513
# 48       0.600726    0.701371    0.345404
# 49       0.777413    0.208011    0.413690
# 50            NaN         NaN         NaN
# 51            NaN         NaN         NaN
# 52       0.795827    0.037292    0.318479
# 53       0.102240    0.092183    0.617916
# 54       0.231848    0.301982    0.447544
# 55       0.574874    0.039269    0.622456
# 56       0.355203    0.584419    0.584410
# 57       0.438441    0.075098    0.361368
# 58       0.050809    0.241483    0.505284

# %%
df = df.sort_values('Gene')

# %%
df.to_excel(out_report + '/burden_all.xlsx', index = False)

# %%
print "***** Please find path of output report here: ", out_report + '/burden_all.xlsx'
# Out:
# ***** Please find path of output report here:  /data/BurdenTest/Lithiasis_mar/output/report/burden_all.xlsx
